# %% [markdown]
# <a href="https://colab.research.google.com/github/zhouqic4/MSSP607-GitHub/blob/main/WeeklyModules/Week02/Zhouqi_Week2_participation_activity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
spam = [2,4,6,8,10]
spam
# Out:
# [2, 4, 6, 8, 10]

# %%
spam[2]='hello'
spam
# Out:
# [2, 4, 'hello', 8, 10]

# %%
letters = ['a', 'b', 'c', 'd']
letters
# Out:
# ['a', 'b', 'c', 'd']

# %%
letters[int(int('3'*2)//11)]
#'3'*2 repeats the string and gives '33' but the number of 6. int('33')is 33,
# and 33//11 is 3 using floored division. The outer int() leaves the 3 alone,
#so the expression is letters[3], the fourth item in the list.(count from 0)
# Out:
# 'd'

# %%
letters[-1]
#count backs from the end. so it's last item
# Out:
# 'd'

# %%
letters[:2]
# a slice with no start begins at index 0 and stops before index 2,
#so it returns a new list holding the first two items. a slice give back a whole
#list but not a single item
# Out:
# ['a', 'b']

# %%
letters_tuple = tuple(letters)
letters_tuple
# Out:
# ('a', 'b', 'c', 'd')

# %%
letters_list=[1,2,3,4]
letters_list
# Out:
# [1, 2, 3, 4]

# %%
letters_list=list(letters_tuple)
print(letters_list)
# Out:
# ['a', 'b', 'c', 'd']

# %%
def comma_code(items):
  #try to return an empty string result when list has no items
  #why not printable :(

  items= [str(item) for item in items]
  if len(items) == 0:
    return ''

  elif len(items) == 1:
    return items[0]

  elif len(items) == 2:
    return items[0] + ' and ' + items[1]

  else:
    return ', '.join(items[:-1]) + ', and ' + items[-1]

# %%
spam = ['apples', 'bananas', 'tofu', 'cats']
comma_code(spam)
# Out:
# 'apples, bananas, tofu, and cats'
